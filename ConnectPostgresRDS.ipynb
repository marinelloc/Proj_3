# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
host = 'evchargerdb.cjlsbfswobs8.us-east-1.rds.amazonaws.com'
database = 'evchargerinst'
user = 'postgres'
password = 'charger2024'
port = '5432'

# %%
conn = psycopg2.connect(
    host=host,
    database=database,
    user=user,
    password=password,
    port=port
)

# %%
def test_connection(host, port, database, user, password):
    try:
        # Attempt to connect to the database
        conn = psycopg2.connect(
            host=host,
            port=port,
            database=database,
            user=user,
            password=password
        )
        # If connection is successful, print success message
        print("Connection successful!")
        # Close the connection
        conn.close()
    except psycopg2.Error as e:
        # If connection fails, print error message
        print("Connection failed:", e)

# Test the connection
test_connection(host, port, database, user, password)
# Out:
# Connection successful!

# %%
query = 'SELECT * FROM "evChargers".evchargers_northeast_v env;'

# %%
df = pd.read_sql_query(query, conn)
# Out:
# C:\Users\alawr\AppData\Local\Temp\ipykernel_11160\1553155693.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
df.head()
# Out:
#   fuel type code                                       station name  \
# 0           ELEC                             Element Hotels - Ewing
# 1           ELEC                      PALMER SQUARE CHAMBERS GARAGE
# 2           ELEC       Giant Eagle - Market District Settlers Ridge
# 3           ELEC                    Giant Eagle #43 - Pine Township
# 4           ELEC  Elizabeth Parking Authority - J Christian Boll...
#
#                  street address        city state zipcode  station phone  \
# 0          1000 Sam Weinroth Rd       Ewing    NJ     8628  609-671-0050
# 1                25 Chambers St   Princeton    NJ     8542  888-758-4389
# 2  100 Settlers Ridge Centre Dr  Pittsburgh    PA    15205  412-788-5392
# 3           155 Towne Center Dr     Wexford    PA    15090  724-934-0155
# 4                37 Caldwell Pl   Elizabeth    NJ     7201  908-353-0949
#
#   status code            groups with access code  \
# 0           E                             Public
# ...

# %%
df.columns
# Out:
# Index(['fuel type code', 'station name', 'street address', 'city', 'state',
#        'zipcode ', 'station phone', 'status code', 'groups with access code',
#        'access days time', 'cards accepted', 'ev level1 evse num',
#        'ev level2 evse num', 'ev dc fast count', 'ev other info', 'ev network',
#        'geocode status', 'latitude', 'longitude', 'date last confirmed', 'id',
#        'updated at', 'owner type code', 'federal agency id',
#        'federal agency name', 'open date', 'ev connector types', 'country',
#        'bd blends (french)', 'groups with access code (french)', 'access code',
#        'facility type', 'ev pricing', 'ev on-site renewable source',
#        'restricted access', 'maximum vehicle class', 'ev workplace charging'],
#       dtype='object')

# %%
nj_rows = df[df['state'] == 'NJ']
nj_rows['zipcode '] = nj_rows['zipcode '].apply(lambda x: x.zfill(5))
df.update(nj_rows)
# Out:
# C:\Users\alawr\AppData\Local\Temp\ipykernel_11160\1941530424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nj_rows['zipcode '] = nj_rows['zipcode '].apply(lambda x: x.zfill(5))

# %%
df.head()
# Out:
#   fuel type code                                       station name  \
# 0           ELEC                             Element Hotels - Ewing
# 1           ELEC                      PALMER SQUARE CHAMBERS GARAGE
# 2           ELEC       Giant Eagle - Market District Settlers Ridge
# 3           ELEC                    Giant Eagle #43 - Pine Township
# 4           ELEC  Elizabeth Parking Authority - J Christian Boll...
#
#                  street address        city state zipcode  station phone  \
# 0          1000 Sam Weinroth Rd       Ewing    NJ    08628  609-671-0050
# 1                25 Chambers St   Princeton    NJ    08542  888-758-4389
# 2  100 Settlers Ridge Centre Dr  Pittsburgh    PA    15205  412-788-5392
# 3           155 Towne Center Dr     Wexford    PA    15090  724-934-0155
# 4                37 Caldwell Pl   Elizabeth    NJ    07201  908-353-0949
#
#   status code            groups with access code  \
# 0           E                             Public
# ...

# %%
selected_columns = df[['station name', 'street address', 'city', 'state', 'country', 'zipcode ','latitude', 'longitude', 'ev network']]
updated_df = selected_columns

updated_df.head()
# Out:
#                                         station name  \
# 0                             Element Hotels - Ewing
# 1                      PALMER SQUARE CHAMBERS GARAGE
# 2       Giant Eagle - Market District Settlers Ridge
# 3                    Giant Eagle #43 - Pine Township
# 4  Elizabeth Parking Authority - J Christian Boll...
#
#                  street address        city state country zipcode    latitude  \
# 0          1000 Sam Weinroth Rd       Ewing    NJ      US    08628  40.286520
# 1                25 Chambers St   Princeton    NJ      US    08542  40.350117
# 2  100 Settlers Ridge Centre Dr  Pittsburgh    PA      US    15205  40.441450
# 3           155 Towne Center Dr     Wexford    PA      US    15090  40.632137
# 4                37 Caldwell Pl   Elizabeth    NJ      US    07201  40.663850
#
#    longitude           ev network
# 0 -74.807520        Non-Networked
# 1 -74.662735  ChargePoint Network
# 2 -80.149750        Non-Networked
# 3 -80.054280        Non-Networked
# ...

# %%
# SQL to create the view
view_name = 'evNorthEastCleaned_v'
schema_name = 'evchargers'

# %%
# Define the connection parameters
db_connection_str = 'postgresql://user:password@host:port/database_name'

# Construct the connection string
db_connection_str = f'postgresql://{user}:{password}@{host}:{port}/{database}'

# Define the schema name and view name
schema_name = 'evChargers'
view_name = 'evNorthEast_v'

# Write the DataFrame as a view to the database
updated_df.to_sql(view_name, con=create_engine(db_connection_str), schema=schema_name, if_exists='replace', index=False)
# Out:
# 770

# %%
updated_df.reset_index(drop=True, inplace=True)

# %%
northeast_clean_df = updated_df

# %%
northeast_clean_df.head()
# Out:
#                                         station name  \
# 0                             Element Hotels - Ewing
# 1                      PALMER SQUARE CHAMBERS GARAGE
# 2       Giant Eagle - Market District Settlers Ridge
# 3                    Giant Eagle #43 - Pine Township
# 4  Elizabeth Parking Authority - J Christian Boll...
#
#                  street address        city state country zipcode    latitude  \
# 0          1000 Sam Weinroth Rd       Ewing    NJ      US    08628  40.286520
# 1                25 Chambers St   Princeton    NJ      US    08542  40.350117
# 2  100 Settlers Ridge Centre Dr  Pittsburgh    PA      US    15205  40.441450
# 3           155 Towne Center Dr     Wexford    PA      US    15090  40.632137
# 4                37 Caldwell Pl   Elizabeth    NJ      US    07201  40.663850
#
#    longitude           ev network
# 0 -74.807520        Non-Networked
# 1 -74.662735  ChargePoint Network
# 2 -80.149750        Non-Networked
# 3 -80.054280        Non-Networked
# ...
